# %%
from bs4 import BeautifulSoup
import selenium.webdriver as webdriver
import urllib.parse
import urllib.request
from urllib.request import Request, urlopen
from time import sleep
import pandas as pd

# %%
search= input("검색어를 입력하세요: ")
searching= str(search)
search= urllib.parse.quote(search)
url= 'https://www.instagram.com/explore/tags/'+str(search)+'/'
driver= webdriver.Chrome('c:/chromedriver.exe')
# Out:
# 검색어를 입력하세요: 테라로사

# %% [markdown]
# # 작성자, Hashtag 수집

# %%
driver.get(url)
sleep(3)

SCROLL_PAUSE_TIME= 1.2

# %%
reallink= []

while True:
    pageString= driver.page_source
    bs= BeautifulSoup(pageString, "lxml")
    
    for link1 in bs.find_all(name= "div",attrs= {'class':'Nnq7C weEfm'}):
        title = link1.select('a')[0]
        real= title.attrs['href']
        reallink.append(real)
        title= link1.select('a')[1]
        real= title.attrs['href']
        reallink.append(real)
    
    last_height= driver.execute_script('return document.body.scrollHeight')
    driver.execute_script('window.scrollTo(0, document.body.scrollHeight);')
    sleep(SCROLL_PAUSE_TIME)
    new_height= driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        sleep(SCROLL_PAUSE_TIME)
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        
        else:
            last_height = new_height
            continue

# %%
import pandas_csv

hashtags2= []

reallinknum= len(reallink)
print("총" + str(reallinknum)+"개의 데이터.")

for i in range(0, reallinknum):
    hashtags2.append([])
    req= 'https://www.instagram.com' + reallink[i]
    driver.get(req)
    webpage= driver.page_source
    soup= BeautifulSoup(webpage, "html.parser")
        
    soup1= str(soup.find_all(attrs={'class':'e1e1d'}))
    user_id= soup1.split('href="/')[1].split('/">')[0]
        
    soup1= str(soup.find_all(attrs={'class': 'Nm9Fw'}))
    subValue = 'span'
            
    soup1 = str(soup.find_all(attrs={'class': 'xil3i'}))
    if (soup1=="[]"):
        hashtags = '해쉬태그없음'
        insert_data = {"search": searching,
                        "user_id": user_id,
                       "hashtags": hashtags}
        pandas_csv.to_csv(insert_data)
    else:
        soup2 = soup1.split(',')
        soup2num = len(soup2)
        for j in range(0, soup2num):
            hashtags = soup2[j].split('#')[1].split('</a>')[0]
            print(hashtags)
            insert_data = {"search": searching,
                            "user_id": user_id,
                            "hashtags": hashtags}
            pandas_csv.to_csv(insert_data)
# Out:
# 총13886개의 데이터.
# 수지_남양주
# 갤러리서종
# 폴짝폴짝
# 날씨좋다
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# summervibes
# sunshine🌞
# 테라로사
# 산미너무높아
# 사비in강릉
# 테라로사
# 테라로사커피공장
# 선릉역카페
# 아이스카페라떼
# 남자블레이져
# 블레이져
# 개발자
# 프로그래머
# 프론트엔드
# 남자가을코디
# 남자가을옷
# 취미사진
# 오늘만
# daily
# 커피맛집
# 수영
# 테라로사
# 2020가을
# 추석연휴시작
# 신난다
# 모두해피추석되세요
# 컨셉사진
# 테라로사
# 일상
# 좋아요
# 셀스타그램
# 테라로사
# 테라로사서귀포
# 서귀포카페
# 피칸파이
# 커피
# 폴바셋
# 라떼
# 테라로사
# 퇴근
# 출근
# 모닝커피
# 카페라떼
# 타르트맛집
# 카페스타그램
# 먹스타그램
# 강릉맛집
# 강릉떡맛집
# 강릉먹거리
# 강릉닭강정
# 안목커피거리
# 경포대맛집
# 떡집맛집
# 기정떡
# 경포
# 테라로사
# 주문진
# 속초
# 강릉맘
# 맘스타그램
# 동해맘
# 주문진
# 정동진
# 여행
# 선물
# 부모님
# 춘천맘
# 잔기지떡
# 행사
# 가을
# 기지떡
# 여름떡
# 하늘
# 예쁘다
# 후원
# 떡스타그램
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 따뜻한
# 아메리카노의계절
# 시간이훌쩍
# 예술의전당
# 테라로사
# 핸드드립커피
# coffee
# terarosacoffee
# cafe
# 테라로사
# 담백하지만은않을거야
# 매운맛
# 빨간맛
# 테라로사
# 강원도여행
# 강릉여행
# 드라이브
# 내년을기약하자
# 풀스케줄
# 워커홀릭
# 엔잡러
# 프리랜서
# 필라테스강사
# 한다
# 된다
# Terarosa
# 테라로사
# 수지_남양주
# 갤러리서종
# 폴짝폴짝
# 날씨좋다
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# summervibes
# sunshine🌞
# 테라로사
# 산미너무높아
# 사비in강릉
# 테라로사
# 테라로사커피공장
# 선릉역카페
# 아이스카페라떼
# 남자블레이져
# 블레이져
# 개발자
# 프로그래머
# 프론트엔드
# 남자가을코디
# 남자가을옷
# 취미사진
# 오늘만
# daily
# 커피맛집
# 수영
# 테라로사
# 2020가을
# 추석연휴시작
# 신난다
# 모두해피추석되세요
# 컨셉사진
# 테라로사
# 일상
# 좋아요
# 셀스타그램
# 테라로사
# 테라로사서귀포
# 서귀포카페
# 피칸파이
# 커피
# 폴바셋
# 라떼
# 테라로사
# 퇴근
# 출근
# 모닝커피
# 카페라떼
# 타르트맛집
# 카페스타그램
# 먹스타그램
# 강릉맛집
# 강릉떡맛집
# 강릉먹거리
# 강릉닭강정
# 안목커피거리
# 경포대맛집
# 떡집맛집
# 기정떡
# 경포
# 테라로사
# 주문진
# 속초
# 강릉맘
# 맘스타그램
# 동해맘
# 주문진
# 정동진
# 여행
# 선물
# 부모님
# 춘천맘
# 잔기지떡
# 행사
# 가을
# 기지떡
# 여름떡
# 하늘
# 예쁘다
# 후원
# 떡스타그램
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 따뜻한
# 아메리카노의계절
# 시간이훌쩍
# 예술의전당
# 테라로사
# 핸드드립커피
# coffee
# terarosacoffee
# cafe
# 테라로사
# 담백하지만은않을거야
# 매운맛
# 빨간맛
# 테라로사
# 강원도여행
# 강릉여행
# 드라이브
# 내년을기약하자
# 풀스케줄
# 워커홀릭
# 엔잡러
# 프리랜서
# 필라테스강사
# 한다
# 된다
# Terarosa
# 테라로사
# 선팔
# 맞팔
# 선팔맞팔
# 맞팔해요
# 팔로우
# 좋아요
# 좋아요반사
# 좋반
# 좋반테러
# 좋반환영
# 첫줄
# 첫줄반사
# 첫줄테러
# 첫줄좋아요
# 협찬
# 협찬디엠
# 맞팔해요
# 소통해요
# 헬린이
# 다이어터
# 좋아요
# 울산
# 부산
# 예쁘다
# 예쁘다그램
# 드라이브
# 부산카페
# 망미동카페
# 수영카페
# 수영
# 테라로사
# f1963
# 삼청동
# 테라로사
# 가을
# 인물사진
# ootd
# 다이어트
# 수제비
# 먹고싶다
# 복정식당
# 굴전
# 잉잉
# 🐽
# 막걸리
# terarosa
# テラロッサ
# 韓国カフェ
# 韓国カフェ巡り
# カフェ
# カフェ巡り
# 韓国
# 韓国情報
# 景福宮
# 景福宮カフェ
# 景福宮駅
# 三清洞
# 三清洞カフェ
# サムチョンドン
# 国立現代美術館ソウル館
# 테라로사
# 카페
# 카페스타그램
# 경복궁카페
# 삼청동카페
# 국립현대미술관서울관
# 포스코센터
# 포스코센터맛집
# 테라로사
# 테라로사포스코점
# 강남카페
# 대치동카페
# 애엄마
# 딸맘
# 딸바보
# 딸맘소통
# 육아소통
# 남양주맘
# 서울카페
# 선정릉카페
# 서울카페
# 테라로사
# 포스코센터
# 포스코센터맛집
# 테라로사포스코점
# 강남카페
# 애엄마
# 애엄마그램
# 애엄마일상
# 줌마그램
# 남양주맘
# 미사맘
# 28개월아기
# 딸맘
# 딸바보
# 딸맘소통
# 육아소통
# 줌마그램
# 자유부인
# 테라로사
# 테라로사동탄
# 테라로사굿즈
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# 테라로사커피공장
# daily
# dailylook
# dailygram
# instagood
# instagram
# instadaily
# instalike
# insta
# selfie
# selca
# selsta
# selstagram
# fff
# f4
# f４f
# f4follow
# 수지_남양주
# 갤러리서종
# 폴짝폴짝
# 날씨좋다
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# summervibes
# sunshine🌞
# 테라로사
# 산미너무높아
# 사비in강릉
# 테라로사
# 테라로사커피공장
# 선릉역카페
# 아이스카페라떼
# 남자블레이져
# 블레이져
# 개발자
# 프로그래머
# 프론트엔드
# 남자가을코디
# 남자가을옷
# 취미사진
# 오늘만
# daily
# 커피맛집
# 수영
# 테라로사
# 2020가을
# 추석연휴시작
# 신난다
# 모두해피추석되세요
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 따뜻한
# 아메리카노의계절
# 시간이훌쩍
# 예술의전당
# 테라로사
# 핸드드립커피
# coffee
# terarosacoffee
# cafe
# 테라로사
# 담백하지만은않을거야
# 매운맛
# 빨간맛
# 테라로사
# 강원도여행
# 강릉여행
# 드라이브
# 내년을기약하자
# 풀스케줄
# 워커홀릭
# 엔잡러
# 프리랜서
# 필라테스강사
# 한다
# 된다
# Terarosa
# 테라로사
# 선팔
# 맞팔
# 선팔맞팔
# 맞팔해요
# 팔로우
# 좋아요
# 좋아요반사
# 좋반
# 좋반테러
# 좋반환영
# 첫줄
# 첫줄반사
# 첫줄테러
# 첫줄좋아요
# 협찬
# 협찬디엠
# 맞팔해요
# 소통해요
# 헬린이
# 다이어터
# 좋아요
# 울산
# 부산
# 예쁘다
# 예쁘다그램
# 드라이브
# 부산카페
# 망미동카페
# 수영카페
# 수영
# 테라로사
# f1963
# 삼청동
# 테라로사
# 가을
# 인물사진
# ootd
# 다이어트
# 수제비
# 먹고싶다
# 복정식당
# 굴전
# 잉잉
# 🐽
# 막걸리
# terarosa
# テラロッサ
# 韓国カフェ
# 韓国カフェ巡り
# カフェ
# カフェ巡り
# 韓国
# 韓国情報
# 景福宮
# 景福宮カフェ
# 景福宮駅
# 三清洞
# 三清洞カフェ
# サムチョンドン
# 国立現代美術館ソウル館
# 테라로사
# 카페
# 카페스타그램
# 경복궁카페
# 삼청동카페
# 국립현대미술관서울관
# 포스코센터
# 포스코센터맛집
# 테라로사
# 테라로사포스코점
# 강남카페
# 대치동카페
# 애엄마
# 딸맘
# 딸바보
# 딸맘소통
# 육아소통
# 남양주맘
# 서울카페
# 선정릉카페
# 서울카페
# 테라로사
# 포스코센터
# 포스코센터맛집
# 테라로사포스코점
# 강남카페
# 애엄마
# 애엄마그램
# 애엄마일상
# 줌마그램
# 남양주맘
# 미사맘
# 28개월아기
# 딸맘
# 딸바보
# 딸맘소통
# 육아소통
# 줌마그램
# 자유부인
# 테라로사
# 테라로사동탄
# 테라로사굿즈
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# 테라로사커피공장
# daily
# dailylook
# dailygram
# instagood
# instagram
# instadaily
# instalike
# insta
# selfie
# selca
# selsta
# selstagram
# fff
# f4
# f４f
# f4follow
# 동탄호수공원
# 테라로사
# 일상
# 일상스타그램
# 데일리
# 소통
# 팔로우
# 좋아요반사
# 좋반
# 04년생
# 고1
# 17
# 용인
# 오산
# 세교
# selfie
# coffee
# coffeetime
# instagood
# instagram
# likelike
# likeforfollow
# instalike
# daily
# dailygram
# likeforlikes
# likeforlikeback
# フォロー
# いいね歓迎
# いいね返し
# 테라로사
# 테라로사커피공장
# 테라로사경포호수점
# 강릉
# 강릉여행
# 여행
# 힐링
# 여유
# 강릉카페
# 셀카
# 데일리
# 데일리룩
# 소통
# 여행스타그램
# 강릉맛집
# 카페
# 테라로사
# 테라로사커피공장
# 강릉
# 강릉여행
# 여행
# 힐링
# 여유
# 강릉카페
# 셀카
# 데일리
# 데일리룩
# 소통
# 여행스타그램
# 강릉맛집
# 동탄카페
# 테라로사
# 카페라떼
# 맛쟁이_동탄
# 동탄맛집
# 동탄호수공원
# 동탄맘
# 동탄2맛집
# 동탄데이트
# 테라로사동탄호수점
# 카페라떼맛집
# 부산수영구카페
# 테라로사
# 힐링스팟
# 좋반
# 좋반테러
# 루미니크
# 키큰여자
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 수지_남양주
# 갤러리서종
# 폴짝폴짝
# 날씨좋다
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# summervibes
# sunshine🌞
# 테라로사
# 산미너무높아
# 사비in강릉
# 테라로사
# 테라로사커피공장
# 선릉역카페
# 아이스카페라떼
# 남자블레이져
# 블레이져
# 개발자
# 프로그래머
# 프론트엔드
# 남자가을코디
# 남자가을옷
# 취미사진
# 오늘만
# daily
# 커피맛집
# 수영
# 테라로사
# 2020가을
# 추석연휴시작
# 신난다
# 모두해피추석되세요
# 따뜻한
# 아메리카노의계절
# 시간이훌쩍
# 예술의전당
# 테라로사
# 핸드드립커피
# coffee
# terarosacoffee
# cafe
# 테라로사
# 담백하지만은않을거야
# 매운맛
# 빨간맛
# 테라로사
# 강원도여행
# 강릉여행
# 드라이브
# 내년을기약하자
# 풀스케줄
# 워커홀릭
# 엔잡러
# 프리랜서
# 필라테스강사
# 한다
# 된다
# Terarosa
# 테라로사
# 선팔
# 맞팔
# 선팔맞팔
# 맞팔해요
# 팔로우
# 좋아요
# 좋아요반사
# 좋반
# 좋반테러
# 좋반환영
# 첫줄
# 첫줄반사
# 첫줄테러
# 첫줄좋아요
# 협찬
# 협찬디엠
# 맞팔해요
# 소통해요
# 헬린이
# 다이어터
# 좋아요
# 울산
# 부산
# 예쁘다
# 예쁘다그램
# 드라이브
# 부산카페
# 망미동카페
# 수영카페
# 수영
# 테라로사
# f1963
# 삼청동
# 테라로사
# 가을
# 인물사진
# ootd
# 다이어트
# 수제비
# 먹고싶다
# 복정식당
# 굴전
# 잉잉
# 🐽
# 막걸리
# terarosa
# テラロッサ
# 韓国カフェ
# 韓国カフェ巡り
# カフェ
# カフェ巡り
# 韓国
# 韓国情報
# 景福宮
# 景福宮カフェ
# 景福宮駅
# 三清洞
# 三清洞カフェ
# サムチョンドン
# 国立現代美術館ソウル館
# 테라로사
# 카페
# 카페스타그램
# 경복궁카페
# 삼청동카페
# 국립현대미술관서울관
# 포스코센터
# 포스코센터맛집
# 테라로사
# 테라로사포스코점
# 강남카페
# 대치동카페
# 애엄마
# 딸맘
# 딸바보
# 딸맘소통
# 육아소통
# 남양주맘
# 서울카페
# 선정릉카페
# 서울카페
# 테라로사
# 포스코센터
# 포스코센터맛집
# 테라로사포스코점
# 강남카페
# 애엄마
# 애엄마그램
# 애엄마일상
# 줌마그램
# 남양주맘
# 미사맘
# 28개월아기
# 딸맘
# 딸바보
# 딸맘소통
# 육아소통
# 줌마그램
# 자유부인
# 테라로사
# 테라로사동탄
# 테라로사굿즈
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# 테라로사커피공장
# daily
# dailylook
# dailygram
# instagood
# instagram
# instadaily
# instalike
# insta
# selfie
# selca
# selsta
# selstagram
# fff
# f4
# f４f
# f4follow
# 동탄호수공원
# 테라로사
# 일상
# 일상스타그램
# 데일리
# 소통
# 팔로우
# 좋아요반사
# 좋반
# 04년생
# 고1
# 17
# 용인
# 오산
# 세교
# selfie
# coffee
# coffeetime
# instagood
# instagram
# likelike
# likeforfollow
# instalike
# daily
# dailygram
# likeforlikes
# likeforlikeback
# フォロー
# いいね歓迎
# いいね返し
# 테라로사
# 테라로사커피공장
# 테라로사경포호수점
# 강릉
# 강릉여행
# 여행
# 힐링
# 여유
# 강릉카페
# 셀카
# 데일리
# 데일리룩
# 소통
# 여행스타그램
# 강릉맛집
# 카페
# 테라로사
# 테라로사커피공장
# 강릉
# 강릉여행
# 여행
# 힐링
# 여유
# 강릉카페
# 셀카
# 데일리
# 데일리룩
# 소통
# 여행스타그램
# 강릉맛집
# 동탄카페
# 테라로사
# 카페라떼
# 맛쟁이_동탄
# 동탄맛집
# 동탄호수공원
# 동탄맘
# 동탄2맛집
# 동탄데이트
# 테라로사동탄호수점
# 카페라떼맛집
# 부산수영구카페
# 테라로사
# 힐링스팟
# 좋반
# 좋반테러
# 루미니크
# 키큰여자
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 양평
# 두물머리
# 테라로사
# 아직끝나지않은생일
# 이따영화보면서허니콤보먹자
# 신혼여행
# 강원도
# 강릉
# 테라로사
# 커알못
# 그래서나는쥬스
# 구남친과
# 심야데이트
# 테라로사
# 여행스타그램
# 강원도여행
# 강원도카페
# 강릉여행
# 스테이인터뷰
# 테라로사
# 커피콩빵
# bts정류장
# travel
# travelgram
# lookdodia
# 🇰🇷
# 수지_남양주
# 갤러리서종
# 폴짝폴짝
# 날씨좋다
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# summervibes
# sunshine🌞
# 테라로사
# 산미너무높아
# 사비in강릉
# 테라로사
# 테라로사커피공장
# 선릉역카페
# 아이스카페라떼
# 남자블레이져
# 블레이져
# 개발자
# 프로그래머
# 프론트엔드
# 남자가을코디
# 남자가을옷
# 취미사진
# 오늘만
# daily
# 커피맛집
# 수영
# 테라로사
# 2020가을
# 추석연휴시작
# 신난다
# 모두해피추석되세요
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# 테라로사커피공장
# daily
# dailylook
# dailygram
# instagood
# instagram
# instadaily
# instalike
# insta
# selfie
# selca
# selsta
# selstagram
# fff
# f4
# f４f
# f4follow
# 동탄호수공원
# 테라로사
# 일상
# 일상스타그램
# 데일리
# 소통
# 팔로우
# 좋아요반사
# 좋반
# 04년생
# 고1
# 17
# 용인
# 오산
# 세교
# selfie
# coffee
# coffeetime
# instagood
# instagram
# likelike
# likeforfollow
# instalike
# daily
# dailygram
# likeforlikes
# likeforlikeback
# フォロー
# いいね歓迎
# いいね返し
# 테라로사
# 테라로사커피공장
# 테라로사경포호수점
# 강릉
# 강릉여행
# 여행
# 힐링
# 여유
# 강릉카페
# 셀카
# 데일리
# 데일리룩
# 소통
# 여행스타그램
# 강릉맛집
# 카페
# 테라로사
# 테라로사커피공장
# 강릉
# 강릉여행
# 여행
# 힐링
# 여유
# 강릉카페
# 셀카
# 데일리
# 데일리룩
# 소통
# 여행스타그램
# 강릉맛집
# 동탄카페
# 테라로사
# 카페라떼
# 맛쟁이_동탄
# 동탄맛집
# 동탄호수공원
# 동탄맘
# 동탄2맛집
# 동탄데이트
# 테라로사동탄호수점
# 카페라떼맛집
# 부산수영구카페
# 테라로사
# 힐링스팟
# 좋반
# 좋반테러
# 루미니크
# 키큰여자
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 양평
# 두물머리
# 테라로사
# 아직끝나지않은생일
# 이따영화보면서허니콤보먹자
# 신혼여행
# 강원도
# 강릉
# 테라로사
# 커알못
# 그래서나는쥬스
# 구남친과
# 심야데이트
# 테라로사
# 여행스타그램
# 강원도여행
# 강원도카페
# 강릉여행
# 스테이인터뷰
# 테라로사
# 커피콩빵
# bts정류장
# travel
# travelgram
# lookdodia
# 🇰🇷
# jeju
# 강릉여행
# 테라로사
# 카페투어
# 테라로사
# 테라로사광화문
# 퇴근후
# 커피
# 라떼
# 비밀정원
# 정원
# 너무
# 예뻐
# 아악
# 카페
# 테라로사
# 테라로사커피공장
# 대학생
# 휴학생
# 일상
# ❣️
# 강릉오면
# 테라로사
# 꼭
# 가세요
# 나는
# 멍청이
# 테라로사커피공장
# 대학생
# 휴학생
# 일상
# ❣️
# 줌마들여행
# 마지막코스
# 테라로사
# 커피타임
# 가을여행
# 숏트립
# 현실속으로
# 하룻밤의꿈
# 꿈이냐생시냐
# 저녁준비실화냐
# 잠시마실갔다온느낌
# today
# dailypic
# shorttrip
# friendship
# enjoy
# seeagain
# lifestyle
# likeforlikes
# likeforfollow
# 까눌레
# 테라로사
# 오뗄두스
# 랑꼬뉴
# 카눌레
# 괜히빨대호로록
# 수지_남양주
# 갤러리서종
# 폴짝폴짝
# 날씨좋다
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# summervibes
# sunshine🌞
# 테라로사
# 산미너무높아
# 사비in강릉
# 테라로사
# 테라로사커피공장
# 선릉역카페
# 아이스카페라떼
# 남자블레이져
# 블레이져
# 개발자
# 프로그래머
# 프론트엔드
# 남자가을코디
# 남자가을옷
# 취미사진
# 오늘만
# daily
# 커피맛집
# 수영
# 테라로사
# 2020가을
# 추석연휴시작
# 신난다
# 모두해피추석되세요
# 테라로사
# 테라로사커피공장
# 강릉
# 강릉여행
# 여행
# 힐링
# 여유
# 강릉카페
# 셀카
# 데일리
# 데일리룩
# 소통
# 여행스타그램
# 강릉맛집
# 동탄카페
# 테라로사
# 카페라떼
# 맛쟁이_동탄
# 동탄맛집
# 동탄호수공원
# 동탄맘
# 동탄2맛집
# 동탄데이트
# 테라로사동탄호수점
# 카페라떼맛집
# 부산수영구카페
# 테라로사
# 힐링스팟
# 좋반
# 좋반테러
# 루미니크
# 키큰여자
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 양평
# 두물머리
# 테라로사
# 아직끝나지않은생일
# 이따영화보면서허니콤보먹자
# 신혼여행
# 강원도
# 강릉
# 테라로사
# 커알못
# 그래서나는쥬스
# 구남친과
# 심야데이트
# 테라로사
# 여행스타그램
# 강원도여행
# 강원도카페
# 강릉여행
# 스테이인터뷰
# 테라로사
# 커피콩빵
# bts정류장
# travel
# travelgram
# lookdodia
# 🇰🇷
# jeju
# 강릉여행
# 테라로사
# 카페투어
# 테라로사
# 테라로사광화문
# 퇴근후
# 커피
# 라떼
# 비밀정원
# 정원
# 너무
# 예뻐
# 아악
# 카페
# 테라로사
# 테라로사커피공장
# 대학생
# 휴학생
# 일상
# ❣️
# 강릉오면
# 테라로사
# 꼭
# 가세요
# 나는
# 멍청이
# 테라로사커피공장
# 대학생
# 휴학생
# 일상
# ❣️
# 줌마들여행
# 마지막코스
# 테라로사
# 커피타임
# 가을여행
# 숏트립
# 현실속으로
# 하룻밤의꿈
# 꿈이냐생시냐
# 저녁준비실화냐
# 잠시마실갔다온느낌
# today
# dailypic
# shorttrip
# friendship
# enjoy
# seeagain
# lifestyle
# likeforlikes
# likeforfollow
# 까눌레
# 테라로사
# 오뗄두스
# 랑꼬뉴
# 카눌레
# 괜히빨대호로록
# 테라로사
# 제주
# 카푸치노
# 독서타임
# 커피
# 이제집에가야지
# 그만놀아
# Terarosa
# 테라로사
# 테라로사커피공장
# 강릉카페
# 강원도카페
# coffeeshop
# coffeetime
# brunch
# coffee
# cafe
# cafestagram
# koreacafe
# instacafe
# magazine
# interior
# 감성카페
# 카페인테리어
# 인테리어디자인
# 신상카페
# 공간디자인
# 카페일상
# 카페투어
# 핫플레이스
# lamarzeocco
# verse
# synesso
# 테라로사
# TERAROSA
# 테라로사커피
# 중고서점
# 그옆
# 테라로사
# 못지나침
# 테라로사
# 강원도여행
# 신혼여행
# 테라로사본점
# 커피맛이좋구려
# 커피맛집
# 콥휘한잔☕
# 커피
# 테라로사
# 동탄
# 친친
# 수지_남양주
# 갤러리서종
# 폴짝폴짝
# 날씨좋다
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# summervibes
# sunshine🌞
# 테라로사
# 산미너무높아
# 사비in강릉
# 테라로사
# 테라로사커피공장
# 선릉역카페
# 아이스카페라떼
# 남자블레이져
# 블레이져
# 개발자
# 프로그래머
# 프론트엔드
# 남자가을코디
# 남자가을옷
# 취미사진
# 오늘만
# daily
# 커피맛집
# 수영
# 테라로사
# 2020가을
# 추석연휴시작
# 신난다
# 모두해피추석되세요
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 카페탐방
# 카페투어
# 카페추천
# 카페인테리어
# 카페사진
# 탐앤탐스
# 커피
# 커피스타그램
# 커피맛집
# 멋진카페발견
# 크리스피크림
# 멋진카페
# 던킨도너츠
# 테라로사
# 멋진인테리어
# 스타벅스
# 양평
# 두물머리
# 테라로사
# 아직끝나지않은생일
# 이따영화보면서허니콤보먹자
# 신혼여행
# 강원도
# 강릉
# 테라로사
# 커알못
# 그래서나는쥬스
# 구남친과
# 심야데이트
# 테라로사
# 여행스타그램
# 강원도여행
# 강원도카페
# 강릉여행
# 스테이인터뷰
# 테라로사
# 커피콩빵
# bts정류장
# travel
# travelgram
# lookdodia
# 🇰🇷
# jeju
# 강릉여행
# 테라로사
# 카페투어
# 테라로사
# 테라로사광화문
# 퇴근후
# 커피
# 라떼
# 비밀정원
# 정원
# 너무
# 예뻐
# 아악
# 카페
# 테라로사
# 테라로사커피공장
# 대학생
# 휴학생
# 일상
# ❣️
# 강릉오면
# 테라로사
# 꼭
# 가세요
# 나는
# 멍청이
# 테라로사커피공장
# 대학생
# 휴학생
# 일상
# ❣️
# 줌마들여행
# 마지막코스
# 테라로사
# 커피타임
# 가을여행
# 숏트립
# 현실속으로
# 하룻밤의꿈
# 꿈이냐생시냐
# 저녁준비실화냐
# 잠시마실갔다온느낌
# today
# dailypic
# shorttrip
# friendship
# enjoy
# seeagain
# lifestyle
# likeforlikes
# likeforfollow
# 까눌레
# 테라로사
# 오뗄두스
# 랑꼬뉴
# 카눌레
# 괜히빨대호로록
# 테라로사
# 제주
# 카푸치노
# 독서타임
# 커피
# 이제집에가야지
# 그만놀아
# Terarosa
# 테라로사
# 테라로사커피공장
# 강릉카페
# 강원도카페
# coffeeshop
# coffeetime
# brunch
# coffee
# cafe
# cafestagram
# koreacafe
# instacafe
# magazine
# interior
# 감성카페
# 카페인테리어
# 인테리어디자인
# 신상카페
# 공간디자인
# 카페일상
# 카페투어
# 핫플레이스
# lamarzeocco
# verse
# synesso
# 테라로사
# TERAROSA
# 테라로사커피
# 중고서점
# 그옆
# 테라로사
# 못지나침
# 테라로사
# 강원도여행
# 신혼여행
# 테라로사본점
# 커피맛이좋구려
# 커피맛집
# 콥휘한잔☕
# 커피
# 테라로사
# 동탄
# 친친
# 테라로사
# 테라로사서귀포
# 제주
# 제주여행
# 엄마랑딸
# 힐링
# 사진
# 사진스타그램
# 소소한일상
# 일상
# 일상스타그램
# daily
# 감성
# 감성사진
# 데일리
# 기록
# 아이폰
# 소통
# 소확행
# 행복
# ootd
# selca
# fff
# 좋아요
# 첫줄
# f4f
# 오오티디
# 네일
# 가을네일
# 네일스타그램
# 셀스타그램
# 셀카
# 테라로사
# 카페
# cafe
# 필테
# 운동중독
# pilateslovers💕
# 필라테스
# 조선희쌤
# 운동
# 카페투어
# 드라이브
# 운동복
# 필라테스복
# 평상복
# 운동하는여자
# 기구운동
# 신논현필라테스
# 필라테스
# 강남필라테스
# 강남필테
# pilates
# 더센터오브필라테스
# 더센터오브필라테스신논현
# pilateslovers
# 테라로사
# 나인블럭
# 테라로사
# 풀문블렌드
# 어센틱에스프레소
# 에디오피아시다모하베고나
# 제주도
# 카페
# カフェ
# 테라로사
# 제주
# 신행
# 제주신행
# 테라로사
# 테라로사서귀포점
# 서귀포카페
# 제주도카페
# 서귀포카페추천
# 강원도여행
# 강릉
# 하슬라아트월드
# 테라로사
# 정동진
# 가을바다
# 휴가
# 여행스타그램
# 경포해변
# 휘닉스평창
# 루지
# 테라로사
# 수지_남양주
# 갤러리서종
# 폴짝폴짝
# 날씨좋다
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# summervibes
# sunshine🌞
# 테라로사
# 산미너무높아
# 사비in강릉
# 테라로사
# 테라로사커피공장
# 선릉역카페
# 아이스카페라떼
# 남자블레이져
# 블레이져
# 개발자
# 프로그래머
# 프론트엔드
# 남자가을코디
# 남자가을옷
# 취미사진
# 오늘만
# daily
# 커피맛집
# 수영
# 테라로사
# 2020가을
# 추석연휴시작
# 신난다
# 모두해피추석되세요
# 카페투어
# 테라로사
# 테라로사광화문
# 퇴근후
# 커피
# 라떼
# 비밀정원
# 정원
# 너무
# 예뻐
# 아악
# 카페
# 테라로사
# 테라로사커피공장
# 대학생
# 휴학생
# 일상
# ❣️
# 강릉오면
# 테라로사
# 꼭
# 가세요
# 나는
# 멍청이
# 테라로사커피공장
# 대학생
# 휴학생
# 일상
# ❣️
# 줌마들여행
# 마지막코스
# 테라로사
# 커피타임
# 가을여행
# 숏트립
# 현실속으로
# 하룻밤의꿈
# 꿈이냐생시냐
# 저녁준비실화냐
# 잠시마실갔다온느낌
# today
# dailypic
# shorttrip
# friendship
# enjoy
# seeagain
# lifestyle
# likeforlikes
# likeforfollow
# 까눌레
# 테라로사
# 오뗄두스
# 랑꼬뉴
# 카눌레
# 괜히빨대호로록
# 테라로사
# 제주
# 카푸치노
# 독서타임
# 커피
# 이제집에가야지
# 그만놀아
# Terarosa
# 테라로사
# 테라로사커피공장
# 강릉카페
# 강원도카페
# coffeeshop
# coffeetime
# brunch
# coffee
# cafe
# cafestagram
# koreacafe
# instacafe
# magazine
# interior
# 감성카페
# 카페인테리어
# 인테리어디자인
# 신상카페
# 공간디자인
# 카페일상
# 카페투어
# 핫플레이스
# lamarzeocco
# verse
# synesso
# 테라로사
# TERAROSA
# 테라로사커피
# 중고서점
# 그옆
# 테라로사
# 못지나침
# 테라로사
# 강원도여행
# 신혼여행
# 테라로사본점
# 커피맛이좋구려
# 커피맛집
# 콥휘한잔☕
# 커피
# 테라로사
# 동탄
# 친친
# 테라로사
# 테라로사서귀포
# 제주
# 제주여행
# 엄마랑딸
# 힐링
# 사진
# 사진스타그램
# 소소한일상
# 일상
# 일상스타그램
# daily
# 감성
# 감성사진
# 데일리
# 기록
# 아이폰
# 소통
# 소확행
# 행복
# ootd
# selca
# fff
# 좋아요
# 첫줄
# f4f
# 오오티디
# 네일
# 가을네일
# 네일스타그램
# 셀스타그램
# 셀카
# 테라로사
# 카페
# cafe
# 필테
# 운동중독
# pilateslovers💕
# 필라테스
# 조선희쌤
# 운동
# 카페투어
# 드라이브
# 운동복
# 필라테스복
# 평상복
# 운동하는여자
# 기구운동
# 신논현필라테스
# 필라테스
# 강남필라테스
# 강남필테
# pilates
# 더센터오브필라테스
# 더센터오브필라테스신논현
# pilateslovers
# 테라로사
# 나인블럭
# 테라로사
# 풀문블렌드
# 어센틱에스프레소
# 에디오피아시다모하베고나
# 제주도
# 카페
# カフェ
# 테라로사
# 제주
# 신행
# 제주신행
# 테라로사
# 테라로사서귀포점
# 서귀포카페
# 제주도카페
# 서귀포카페추천
# 강원도여행
# 강릉
# 하슬라아트월드
# 테라로사
# 정동진
# 가을바다
# 휴가
# 여행스타그램
# 경포해변
# 휘닉스평창
# 루지
# 테라로사
# 제주도
# 테라로사
# 감귤따기체험
# 꾸르맛
# 오늘은
# 호지차아이스크림
# 호지차밀크티
# 녹차크로와상
# 족욕
# 개죠아
# 강릉여행1탄
# 강릉여행
# 엄지네포장마차
# 엄지네꼬막비빔밥
# 테라로사
# 커피맛집
# 이제시작
# 테라로사
# terarosa
# terarosacoffee
# 평화스포웰빙
# 수영장
# swimming
# 예술의전당
# 강원도
# 바이올린
# violin
# 가울냄새
# 전시보는재미
# 아트원정대
# coffee
# coffeetime
# seasonchange
# museumtour
# 테라로사
# 아트원정대
# 선을넘지않는녀자들
# 보랏빛밤
# 피오떼
# 가을네일
# 테라로사
# 비자림
# 제주라이딩
# 투어라이딩
# 아직도피곤하다
# 구하우스
# 수지_남양주
# 갤러리서종
# 폴짝폴짝
# 날씨좋다
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# summervibes
# sunshine🌞
# 테라로사
# 산미너무높아
# 사비in강릉
# 테라로사
# 테라로사커피공장
# 선릉역카페
# 아이스카페라떼
# 남자블레이져
# 블레이져
# 개발자
# 프로그래머
# 프론트엔드
# 남자가을코디
# 남자가을옷
# 취미사진
# 오늘만
# daily
# 커피맛집
# 수영
# 테라로사
# 2020가을
# 추석연휴시작
# 신난다
# 모두해피추석되세요
# 필테
# 운동중독
# pilateslovers💕
# 필라테스
# 조선희쌤
# 운동
# 카페투어
# 드라이브
# 운동복
# 필라테스복
# 평상복
# 운동하는여자
# 기구운동
# 신논현필라테스
# 필라테스
# 강남필라테스
# 강남필테
# pilates
# 더센터오브필라테스
# 더센터오브필라테스신논현
# pilateslovers
# 테라로사
# 나인블럭
# 테라로사
# 풀문블렌드
# 어센틱에스프레소
# 에디오피아시다모하베고나
# 제주도
# 카페
# カフェ
# 테라로사
# 제주
# 신행
# 제주신행
# 테라로사
# 테라로사서귀포점
# 서귀포카페
# 제주도카페
# 서귀포카페추천
# 강원도여행
# 강릉
# 하슬라아트월드
# 테라로사
# 정동진
# 가을바다
# 휴가
# 여행스타그램
# 경포해변
# 휘닉스평창
# 루지
# 테라로사
# 제주도
# 테라로사
# 감귤따기체험
# 꾸르맛
# 오늘은
# 호지차아이스크림
# 호지차밀크티
# 녹차크로와상
# 족욕
# 개죠아
# 강릉여행1탄
# 강릉여행
# 엄지네포장마차
# 엄지네꼬막비빔밥
# 테라로사
# 커피맛집
# 이제시작
# 테라로사
# terarosa
# terarosacoffee
# 평화스포웰빙
# 수영장
# swimming
# 예술의전당
# 강원도
# 바이올린
# violin
# 가울냄새
# 전시보는재미
# 아트원정대
# coffee
# coffeetime
# seasonchange
# museumtour
# 테라로사
# 아트원정대
# 선을넘지않는녀자들
# 보랏빛밤
# 피오떼
# 가을네일
# 테라로사
# 비자림
# 제주라이딩
# 투어라이딩
# 아직도피곤하다
# 구하우스
# 홈카페
# 테라로사
# 스타벅스바닐라시럽
# 밀크폼
# 브레빌
# 아이스바닐라라떼
# 바닐라라떼
# 온더테이블
# 홈카페영상
# 오늘아님
# 맛스타그램
# 루지르
# rougir
# 패션
# fashion
# 디자인
# design
# 일상
# 데일리
# 데일리룩
# daily
# dailylook
# 셀카
# 셀피
# 셀스타그램
# selca
# selfie
# selstargram
# ootd
# 신상카페
# 카페투어
# 부산카페
# 해운대카페
# 센텀카페
# 테라로사
# 테라로사부산
# 부산
# 창원
# 마산
# 진해
# 유하다엘
# 테라로사
# 테라로사
# 온두라스
# 도곡동커피편집샵
# 도곡동스페셜티커피
# 매봉역카페
# 갤러리카페
# 커피앤아트
# 카페슈가플럼
# 아트스페이스플럼
# sugarplumbyplum
# 드로잉
# drawing
# plumart
# 롯데시네마도곡
# coffee
# 테라로사
# 커피줄이기
# iphone
# 제주
# 서귀포
# 카페
# 테라로사
# 카푸치노
# 먼가
# 납치당한기분
# 이뻐서
# 당해준다
# 모녀스타그램
# 테라로사
# 강원
# 여행스타그램
# 여행기록
# 가을바다
# 햇살좋음
# 첫줄안녕
# 강릉여행
# 강릉카페
# 숲속
# 마스크필수
# 가을추억
# 테라로사
# 럽스타그램
# 고모랑조카
# 강릉여행
# 커피공장
# 테라로사
# 경포대
# 주문진
# 호린파크
# 핑크물리
# 도깨비촬영장
# 강원도여행코스
# 감성사진
# 현실은
# 다흘림
# 자세히봐야
# 안이쁘다
# 여행
# 일상
# 강릉카페
# 강릉커피
# 커피맛집
# 테라로사
# 테라로사커피공장
# 여행스타그램
# 디저트그램
# 돼지바마카롱
# 티라미수
# 테라로사
# 커피맛집
# 가을되니
# 달달한게더땡긴다
# 감자빵
# 춘천감자밭
# 테라로사
# 일상
# 소통
# 소통해요
# 일상스타그램
# 일상그램
# 좋아요
# 선팔
# 맞팔
# 첫줄안녕
# 데일리
# 오늘
# 데이트
# 여행스타그램
# 럽스타그램
# 먹방
# 인기맛집
# 분위기맛집
# 데이트맛집
# 카페스타그램
# 핫플
# 힙플레이스
# instadaily
# daily
# instaphoto
# photo
# 셀카
# 셀피
# 강릉카페
# 테라로사
# 테라로사커피공장
# 강릉여행
# 강릉
# 여행
# 여행스타그램
# 일상
# 커피
# 커피맛집
# 수지_남양주
# 갤러리서종
# 폴짝폴짝
# 날씨좋다
# 강릉
# 강릉여행
# 강릉카페
# 테라로사
# summervibes
# sunshine🌞
# 테라로사
# 산미너무높아
# 사비in강릉
# 테라로사
# 테라로사커피공장
# 선릉역카페
# 아이스카페라떼
# 남자블레이져
# 블레이져
# 개발자
# 프로그래머
# 프론트엔드
# 남자가을코디
# 남자가을옷
# 취미사진
# 오늘만
# daily
# 커피맛집
# 수영
# 테라로사
# 2020가을
# 추석연휴시작
# 신난다
# 모두해피추석되세요
# 테라로사
# terarosa
# terarosacoffee
# 평화스포웰빙
# 수영장
# swimming
# 예술의전당
# 강원도
# 바이올린
# violin
# 가울냄새
# 전시보는재미
# 아트원정대
# coffee
# coffeetime
# seasonchange
# museumtour
# 테라로사
# 아트원정대
# 선을넘지않는녀자들
# 보랏빛밤
# 피오떼
# 가을네일
# 테라로사
# 비자림
# 제주라이딩
# 투어라이딩
# 아직도피곤하다
# 구하우스
# 홈카페
# 테라로사
# 스타벅스바닐라시럽
# 밀크폼
# 브레빌
# 아이스바닐라라떼
# 바닐라라떼
# 온더테이블
# 홈카페영상
# 오늘아님
# 맛스타그램
# 루지르
# rougir
# 패션
# fashion
# 디자인
# design
# 일상
# 데일리
# 데일리룩
# daily
# dailylook
# 셀카
# 셀피
# 셀스타그램
# selca
# selfie
# selstargram
# ootd
# 신상카페
# 카페투어
# 부산카페
# 해운대카페
# 센텀카페
# 테라로사
# 테라로사부산
# 부산
# 창원
# 마산
# 진해
# 유하다엘
# 테라로사
# 테라로사
# 온두라스
# 도곡동커피편집샵
# 도곡동스페셜티커피
# 매봉역카페
# 갤러리카페
# 커피앤아트
# 카페슈가플럼
# 아트스페이스플럼
# sugarplumbyplum
# 드로잉
# drawing
# plumart
# 롯데시네마도곡
# coffee
# 테라로사
# 커피줄이기
# iphone
# 제주
# 서귀포
# 카페
# 테라로사
# 카푸치노
# 먼가
# 납치당한기분
# 이뻐서
# 당해준다
# 모녀스타그램
# 테라로사
# 강원
# 여행스타그램
# 여행기록
# 가을바다
# 햇살좋음
# 첫줄안녕
# 강릉여행
# 강릉카페
# 숲속
# 마스크필수
# 가을추억
# 테라로사
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-5286d9226b79> in <module>
#      10     req= 'https://www.instagram.com' + reallink[i]
#      11     driver.get(req)
# ---> 12     webpage= driver.page_source
#      13     soup= BeautifulSoup(webpage, "html.parser")
#      14
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      74         if method in self._encode_url_methods:
#      75             return self.request_encode_url(
# ---> 76                 method, url, fields=fields, headers=headers, **urlopen_kw
#      77             )
#      78         else:
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      95             url += "?" + urlencode(fields)
#      96
# ---> 97         return self.urlopen(method, url, **extra_kw)
#      98
#      99     def request_encode_body(
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# c:\ProgramData\Anaconda3\envs\py37\lib\http\client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# c:\ProgramData\Anaconda3\envs\py37\lib\http\client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# c:\ProgramData\Anaconda3\envs\py37\lib\http\client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# c:\ProgramData\Anaconda3\envs\py37\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# # Image Crawl

# %%
import os
os.chdir('C:/Users/soohan/project2020/instagram_crawl_image/')

for i in range(0,reallinknum):
    req= 'https://www.instagram.com' + reallink[i]
    driver.get(req)
    webpage= driver.page_source
    imgsoup= BeautifulSoup(webpage,'html.parser')
    
    if imgsoup.find('img', class_='FFVAD')==None:
        continue
        
# None Type이 아닌 이미지들을 모두 위 경로에 저장
    else:    
        imgurl = imgsoup.find('img', class_= "FFVAD").get('src')
        urllib.request.urlretrieve(imgurl, str(i) +'.jpg')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d5537d9493db> in <module>
#       4 for i in range(0,reallinknum):
#       5     req= 'https://www.instagram.com' + reallink[i]
# ----> 6     driver.get(req)
#       7     webpage= driver.page_source
#       8     imgsoup= BeautifulSoup(webpage,'html.parser')
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     317
#     318         params = self._wrap_value(params)
# --> 319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
#     321             self.error_handler.check_response(response)
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\remote_connection.py in execute(self, command, params)
#     372         data = utils.dump_json(params)
#     373         url = '%s%s' % (self._url, path)
# --> 374         return self._request(command_info[0], url, body=data)
#     375
#     376     def _request(self, method, url, body=None):
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\selenium\webdriver\remote\remote_connection.py in _request(self, method, url, body)
#     395
#     396         if self.keep_alive:
# --> 397             resp = self._conn.request(method, url, body=body, headers=headers)
#     398
#     399             statuscode = resp.status
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      78         else:
#      79             return self.request_encode_body(
# ---> 80                 method, url, fields=fields, headers=headers, **urlopen_kw
#      81             )
#      82
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\request.py in request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     169         extra_kw.update(urlopen_kw)
#     170
# --> 171         return self.urlopen(method, url, **extra_kw)
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     334             response = conn.urlopen(method, url, **kw)
#     335         else:
# --> 336             response = conn.urlopen(method, u.request_uri, **kw)
#     337
#     338         redirect_location = redirect and response.get_redirect_location()
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     675                 body=body,
#     676                 headers=headers,
# --> 677                 chunked=chunked,
#     678             )
#     679
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     424                     # Python 3 (including for exceptions like SystemExit).
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     428             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# c:\ProgramData\Anaconda3\envs\py37\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     419                 # Python 3
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#     423                     # Remove the TypeError from the exception chain in
#
# c:\ProgramData\Anaconda3\envs\py37\lib\http\client.py in getresponse(self)
#    1367         try:
#    1368             try:
# -> 1369                 response.begin()
#    1370             except ConnectionError:
#    1371                 self.close()
#
# c:\ProgramData\Anaconda3\envs\py37\lib\http\client.py in begin(self)
#     308         # read until we get a non-100 response
#     309         while True:
# --> 310             version, status, reason = self._read_status()
#     311             if status != CONTINUE:
#     312                 break
#
# c:\ProgramData\Anaconda3\envs\py37\lib\http\client.py in _read_status(self)
#     269
#     270     def _read_status(self):
# --> 271         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     272         if len(line) > _MAXLINE:
#     273             raise LineTooLong("status line")
#
# c:\ProgramData\Anaconda3\envs\py37\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
